# %% [markdown]
# Датасет: https://www.kaggle.com/datasets/paultimothymooney/denver-crime-data

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Считаем данные из файла

# %%
df = pd.read_csv('C:\\RLib\\crime.csv')
df
# Out:
#         INCIDENT_ID         OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0        2021224206   2021224206220200          2202                       0
# 1        2021225308   2021225308240400          2404                       0
# 2       20216009452  20216009452239900          2399                       0
# 3       20216009439  20216009439230500          2305                       0
# 4       20218017976  20218017976240400          2404                       0
# ...             ...                ...           ...                     ...
# 487992   2021271408   2021271408544100          5441                       0
# 487993   2021271258   2021271258240400          2404                       0
# 487994   2021273338   2021273338299901          2999                       1
# 487995   2021273182   2021273182240400          2404                       0
# 487996   2021273527   2021273527239900          2399                       0
#
#                     OFFENSE_TYPE_ID       OFFENSE_CATEGORY_ID  \
# 0       burglary-residence-by-force                  burglary
# 1            theft-of-motor-vehicle                auto-theft
# 2                       theft-other                   larceny
# 3          theft-items-from-vehicle  theft-from-motor-vehicle
# 4            theft-of-motor-vehicle                auto-theft
# ...                             ...                       ...
# 487992             traffic-accident          traffic-accident
# 487993       theft-of-motor-vehicle                auto-theft
# 487994    criminal-mischief-mtr-veh           public-disorder
# 487995       theft-of-motor-vehicle                auto-theft
# 487996                  theft-other                   larceny
#
#         FIRST_OCCURRENCE_DATE   LAST_OCCURRENCE_DATE          REPORTED_DATE  \
# 0       4/18/2021 10:30:00 PM   4/19/2021 5:00:00 AM   4/21/2021 3:25:00 PM
# 1       4/21/2021 11:25:00 PM                    NaN  4/22/2021 12:01:00 AM
# 2       3/22/2021 12:51:00 PM  3/22/2021 12:51:00 PM  4/21/2021 10:13:00 PM
# 3       4/21/2021 12:00:00 PM  4/21/2021 12:05:00 PM   4/21/2021 1:17:00 PM
# 4        3/9/2021 12:01:00 PM  4/21/2021 12:20:00 PM  4/21/2021 12:20:00 PM
# ...                       ...                    ...                    ...
# 487992   5/14/2021 9:40:00 AM                    NaN   5/14/2021 4:04:00 PM
# 487993   5/13/2021 7:00:00 PM   5/14/2021 7:00:00 AM   5/14/2021 9:12:00 AM
# 487994   5/15/2021 5:22:00 AM   5/15/2021 5:22:00 AM   5/15/2021 6:33:00 AM
# 487995  5/12/2021 10:00:00 PM   5/13/2021 5:30:00 AM   5/15/2021 2:51:00 AM
# 487996   5/12/2021 4:00:00 PM   5/15/2021 8:30:00 AM  5/15/2021 11:32:00 AM
#
#                     INCIDENT_ADDRESS      GEO_X      GEO_Y     GEO_LON  \
# 0                     300 W 11TH AVE  3142828.0  1692472.0 -104.992161
# 1           5700 BLK W DARTMOUTH AVE  3124936.0  1664570.0 -105.056261
# 2                 3412 N HUMBOLDT ST  3149191.0  1703917.0 -104.969299
# 3             1900 BLK S CLARKSON ST  3146781.0  1673727.0 -104.978488
# 4                   24050 E 78TH AVE  3223419.0  1730557.0 -104.704438
# ...                              ...        ...        ...         ...
# 487992  E 22ND AVE / N WASHINGTON ST  3146740.0  1698300.0 -104.978133
# 487993            3000 BLK N ZUNI ST  3136070.0  1702059.0 -105.016008
# 487994          19400 BLK E 39TH AVE  3207858.0  1706079.0 -104.760555
# 487995                7471 E 29TH PL  3168313.0  1701618.0 -104.901335
# 487996              1220 N CORONA ST  3147985.0  1693244.0 -104.973809
#
#           GEO_LAT  DISTRICT_ID  PRECINCT_ID             NEIGHBORHOOD_ID  \
# 0       39.733543          6.0        611.0                civic-center
# 1       39.657203          4.0        423.0                 bear-valley
# 2       39.764862          2.0        211.0                        cole
# 3       39.682023          3.0        313.0                  platt-park
# 4       39.836504          7.0        759.0                         dia
# ...           ...          ...          ...                         ...
# 487992  39.749481          6.0        621.0                 five-points
# 487993  39.759963          1.0        113.0                    highland
# 487994  39.769671          5.0        523.0  gateway-green-valley-ranch
# 487995  39.758224          5.0        512.0                central-park
# 487996  39.735582          6.0        623.0                capitol-hill
#
#         IS_CRIME  IS_TRAFFIC
# 0              1           0
# 1              1           0
# 2              1           0
# 3              1           0
# 4              1           0
# ...          ...         ...
# 487992         0           1
# 487993         1           0
# 487994         1           0
# 487995         1           0
# 487996         1           0
#
# [487997 rows x 19 columns]

# %% [markdown]
# ### 1) Сколько в датасете объектов и признаков? Дать описание каждому признаку, если оно есть.

# %% [markdown]
# Размеры таблицы: 487997 rows × 19 columns => в датасете 487997 объектов и 19 признаков.
#
#     1. INCIDENT_ID - id инцидента(уникальное значение)
#     2. OFFENSE_ID - id правонарушения(уникальное значение)
#     3. OFFENSE_CODE - код правонарушения(категориальное значение)
#     4. OFFENSE_CODE_EXTENSION - код обобщенного правонарушения(категориальное значение)
#     5. OFFENSE_TYPE_ID - правонарушение(категориальное значение)
#     6. OFFENSE_CATEGORY_ID - категория правонарушения(категориальное значение)
#     7. FIRST_OCCURRENCE_DATE - дата первого происшествия(нельзя назвать числовым или категориальным)
#     8. LAST_OCCURRENCE_DATE - дата последнего происшествия(нельзя назвать числовым или категориальным)
#     9. REPORTED_DATE - дата заявления(нельзя назвать числовым или категориальным)
#     10. INCIDENT_ADDRESS - адрес инцидента(нельзя назвать числовым или категориальным)
#     11. GEO_X - (числовое значение)
#     12. GEO_Y - (числовое значение)
#     13. GEO_LON - долгота(числовое значение)
#     14. GEO_LAT - широта(числовое значение)
#     15. DISTRICT_ID - id района(категориальное значение)
#     16. PRECINCT_ID - id избирательного участка(категориальное значение)
#     17. NEIGHBORHOOD_ID - соседство(категориальное значение)
#     18. IS_CRIME - является ли преступлением(бинарное значение)
#     19. IS_TRAFFIC - наличие траффика(бинарное значение)

# %% [markdown]
# ### 2) Сколько категориальных признаков, какие?

# %% [markdown]
# Категориальных признаков 7:
# 1. OFFENSE_CODE
# 2. OFFENSE_CODE_EXTENSION
# 3. OFFENSE_TYPE_ID
# 4. OFFENSE_CATEGORY_ID
# 5. DISTRICT_ID
# 6. PRECINCT_ID
# 7. NEIGHBORHOOD_ID

# %% [markdown]
# ### 3) Столбец с макимальным количеством уникальных значений категориального признака?

# %%
categorical = ['OFFENSE_CODE', 'OFFENSE_CODE_EXTENSION', 'OFFENSE_TYPE_ID', 'OFFENSE_CATEGORY_ID',
'DISTRICT_ID', 'PRECINCT_ID', 'NEIGHBORHOOD_ID']

for column in df.columns:
    if column in categorical:
        print(column, df[column].nunique())
# Out:
# OFFENSE_CODE 155
# OFFENSE_CODE_EXTENSION 6
# OFFENSE_TYPE_ID 200
# OFFENSE_CATEGORY_ID 15
# DISTRICT_ID 7
# PRECINCT_ID 36
# NEIGHBORHOOD_ID 79

# %% [markdown]
# Из описания признаков, приведённого в пункте 1, и из результатов работы функции nunique() видно, что максимальное количество уникальных значений = 200. Оно достигается у параметра OFFENSE_TYPE_ID

# %% [markdown]
# ### 4) Есть ли бинарные признаки?

# %%
i = 1
for column in df.columns:
    if df[column].nunique() == 2:
        print(i, column)
        i += 1
# Out:
# 1 IS_CRIME
# 2 IS_TRAFFIC

# %% [markdown]
# Из описания признаков, приведённого в пункте 1 и из результатов работы функции, выполненной в блоке выше, видно, что бинарными являются 2 признака: IS_CRIME и IS_TRAFFIC

# %% [markdown]
# ### 5) Какие числовые признаки?

# %%
i = 1
for column in df.columns:
    if df[column].nunique() > 200 and column != 'INCIDENT_ADDRESS' and column != 'FIRST_OCCURRENCE_DATE' and column != 'LAST_OCCURRENCE_DATE' and column != 'REPORTED_DATE':
        print(i, column, df[column].nunique())
        i += 1
# Out:
# 1 INCIDENT_ID 455362
# 2 OFFENSE_ID 487997
# 3 GEO_X 47407
# 4 GEO_Y 44975
# 5 GEO_LON 96426
# 6 GEO_LAT 95893

# %% [markdown]
# Из описания признаков, приведённого в пункте 1 и из результатов работы функции, выполненной в блоке выше, видно, что чисто числовыми являются INCIDENT_ID, OFFENSE_ID, GEO_X, GEO_Y, GEO_LON, GEO_LAT.

# %% [markdown]
# ### 6) Есть ли пропуски?

# %%
df.isnull().sum(axis = 0)
# Out:
# INCIDENT_ID                    0
# OFFENSE_ID                     0
# OFFENSE_CODE                   0
# OFFENSE_CODE_EXTENSION         0
# OFFENSE_TYPE_ID                0
# OFFENSE_CATEGORY_ID            0
# FIRST_OCCURRENCE_DATE          0
# LAST_OCCURRENCE_DATE      319926
# REPORTED_DATE                  0
# INCIDENT_ADDRESS           42113
# GEO_X                       4184
# GEO_Y                       4184
# GEO_LON                     4185
# GEO_LAT                     4185
# DISTRICT_ID                    1
# PRECINCT_ID                    1
# NEIGHBORHOOD_ID                1
# IS_CRIME                       0
# IS_TRAFFIC                     0
# dtype: int64

# %% [markdown]
# ### 7) Сколько объектов с пропусками?

# %% [markdown]
# Как видно из результата работы функции isnull().sum(axis = 0), в датасете есть пропуски в LAST_OCCURRENCE_DATE(319926), INCIDENT_ADDRESS(42113), GEO_X и GEO_Y(4184), GEO_LON и GEO_LAT(4185), DISTRICT_ID, PRECINCT_ID и NEIGHBORHOOD_ID(1)

# %% [markdown]
# ### 8) Столбец с максимальным количеством пропусков?

# %% [markdown]
# Из результатов работы функции isnull().sum(axis = 0) видно, что максимальное количество пропусков в столбце LAST_OCCURRENCE_DATE.

# %% [markdown]
# В LAST_OCCURRENCE_DATE очень много пропусков, стоит исключить его из датасета, поскольку в дальнейшем столбец не принесет никакой пользы.
# Также можно исключить столбец INCIDENT_ADDRESS и FIRST_OCCURRENCE_DATE, т.к. в рамках нашей работы он не пригодится.

# %%
df = df.drop(['INCIDENT_ADDRESS', 'LAST_OCCURRENCE_DATE', 'FIRST_OCCURRENCE_DATE'], axis=1)

# %%
df.isnull().sum(axis = 0)
# Out:
# INCIDENT_ID                  0
# OFFENSE_ID                   0
# OFFENSE_CODE                 0
# OFFENSE_CODE_EXTENSION       0
# OFFENSE_TYPE_ID              0
# OFFENSE_CATEGORY_ID          0
# REPORTED_DATE                0
# GEO_X                     4184
# GEO_Y                     4184
# GEO_LON                   4185
# GEO_LAT                   4185
# DISTRICT_ID                  1
# PRECINCT_ID                  1
# NEIGHBORHOOD_ID              1
# IS_CRIME                     0
# IS_TRAFFIC                   0
# dtype: int64

# %% [markdown]
# Уберем оставшиеся строки с пропусками. Их не так уж и много, по сравнению с общим количеством данных.

# %%
df = df.dropna()

# %%
df
# Out:
#         INCIDENT_ID         OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0        2021224206   2021224206220200          2202                       0
# 1        2021225308   2021225308240400          2404                       0
# 2       20216009452  20216009452239900          2399                       0
# 3       20216009439  20216009439230500          2305                       0
# 4       20218017976  20218017976240400          2404                       0
# ...             ...                ...           ...                     ...
# 487992   2021271408   2021271408544100          5441                       0
# 487993   2021271258   2021271258240400          2404                       0
# 487994   2021273338   2021273338299901          2999                       1
# 487995   2021273182   2021273182240400          2404                       0
# 487996   2021273527   2021273527239900          2399                       0
#
#                     OFFENSE_TYPE_ID       OFFENSE_CATEGORY_ID  \
# 0       burglary-residence-by-force                  burglary
# 1            theft-of-motor-vehicle                auto-theft
# 2                       theft-other                   larceny
# 3          theft-items-from-vehicle  theft-from-motor-vehicle
# 4            theft-of-motor-vehicle                auto-theft
# ...                             ...                       ...
# 487992             traffic-accident          traffic-accident
# 487993       theft-of-motor-vehicle                auto-theft
# 487994    criminal-mischief-mtr-veh           public-disorder
# 487995       theft-of-motor-vehicle                auto-theft
# 487996                  theft-other                   larceny
#
#                 REPORTED_DATE      GEO_X      GEO_Y     GEO_LON    GEO_LAT  \
# 0        4/21/2021 3:25:00 PM  3142828.0  1692472.0 -104.992161  39.733543
# 1       4/22/2021 12:01:00 AM  3124936.0  1664570.0 -105.056261  39.657203
# 2       4/21/2021 10:13:00 PM  3149191.0  1703917.0 -104.969299  39.764862
# 3        4/21/2021 1:17:00 PM  3146781.0  1673727.0 -104.978488  39.682023
# 4       4/21/2021 12:20:00 PM  3223419.0  1730557.0 -104.704438  39.836504
# ...                       ...        ...        ...         ...        ...
# 487992   5/14/2021 4:04:00 PM  3146740.0  1698300.0 -104.978133  39.749481
# 487993   5/14/2021 9:12:00 AM  3136070.0  1702059.0 -105.016008  39.759963
# 487994   5/15/2021 6:33:00 AM  3207858.0  1706079.0 -104.760555  39.769671
# 487995   5/15/2021 2:51:00 AM  3168313.0  1701618.0 -104.901335  39.758224
# 487996  5/15/2021 11:32:00 AM  3147985.0  1693244.0 -104.973809  39.735582
#
#         DISTRICT_ID  PRECINCT_ID             NEIGHBORHOOD_ID  IS_CRIME  \
# 0               6.0        611.0                civic-center         1
# 1               4.0        423.0                 bear-valley         1
# 2               2.0        211.0                        cole         1
# 3               3.0        313.0                  platt-park         1
# 4               7.0        759.0                         dia         1
# ...             ...          ...                         ...       ...
# 487992          6.0        621.0                 five-points         0
# 487993          1.0        113.0                    highland         1
# 487994          5.0        523.0  gateway-green-valley-ranch         1
# 487995          5.0        512.0                central-park         1
# 487996          6.0        623.0                capitol-hill         1
#
#         IS_TRAFFIC
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 487992           1
# 487993           0
# 487994           0
# 487995           0
# 487996           0
#
# [483812 rows x 16 columns]

# %%
df.isnull().sum(axis = 0)
# Out:
# INCIDENT_ID               0
# OFFENSE_ID                0
# OFFENSE_CODE              0
# OFFENSE_CODE_EXTENSION    0
# OFFENSE_TYPE_ID           0
# OFFENSE_CATEGORY_ID       0
# REPORTED_DATE             0
# GEO_X                     0
# GEO_Y                     0
# GEO_LON                   0
# GEO_LAT                   0
# DISTRICT_ID               0
# PRECINCT_ID               0
# NEIGHBORHOOD_ID           0
# IS_CRIME                  0
# IS_TRAFFIC                0
# dtype: int64

# %% [markdown]
# ### 9) Есть ли на ваш взгляд выбросы, аномальные значения?

# %%
for column in df.columns:
    print(df[column].value_counts())
# Out:
# 2016233674     8
# 2020498096     7
# 2020613268     7
# 2016134777     6
# 2020315507     6
#               ..
# 2019283912     1
# 2020326341     1
# 2019265475     1
# 2020312002     1
# 20206015261    1
# Name: INCIDENT_ID, Length: 451318, dtype: int64
# 2019499981239900     1
# 2016427293544100     1
# 2021179389549900     1
# 201654149360500      1
# 20203527230300       1
#                     ..
# 2016212426544100     1
# 2019379380351200     1
# 20186007837299901    1
# 2018776196544100     1
# 2016531054299900     1
# Name: OFFENSE_ID, Length: 483812, dtype: int64
# 5441    79474
# 5401    34684
# 2404    33647
# 2999    33431
# 2305    31094
#         ...
# 3804        1
# 6300        1
# 5207        1
# 5303        1
# 5704        1
# Name: OFFENSE_CODE, Length: 150, dtype: int64
# 0    417477
# 1     37410
# 2     25700
# 3      2184
# 5       777
# 4       264
# Name: OFFENSE_CODE_EXTENSION, dtype: int64
# traffic-accident                 79474
# traffic-accident-hit-and-run     34684
# theft-of-motor-vehicle           33647
# theft-items-from-vehicle         31094
# traf-other                       25576
#                                  ...
# liquor-misrepresent-age-minor        1
# bigamy                               1
# riot                                 1
# eavesdropping                        1
# explosives-posses                    1
# Name: OFFENSE_TYPE_ID, Length: 192, dtype: int64
# traffic-accident                117234
# all-other-crimes                 82677
# larceny                          50826
# public-disorder                  50539
# theft-from-motor-vehicle         45821
# auto-theft                       34410
# drug-alcohol                     26674
# burglary                         24861
# other-crimes-against-persons     23457
# aggravated-assault               13264
# white-collar-crime                6639
# robbery                           6390
# arson                              661
# murder                             359
# Name: OFFENSE_CATEGORY_ID, dtype: int64
# 6/1/2020 12:30:00 AM     20
# 6/2/2020 12:25:00 AM     19
# 5/31/2020 10:30:00 PM    18
# 5/31/2020 10:00:00 PM    16
# 6/24/2020 10:12:00 AM    16
#                          ..
# 9/4/2019 10:27:00 AM      1
# 1/7/2017 11:52:00 PM      1
# 7/9/2017 8:26:00 AM       1
# 4/7/2019 8:50:00 AM       1
# 8/19/2019 5:45:00 AM      1
# Name: REPORTED_DATE, Length: 409552, dtype: int64
# 3144130.0    2054
# 3142418.0    1596
# 3231977.0    1570
# 3142778.0    1472
# 3143312.0    1428
#              ...
# 3160144.0       1
# 3205725.0       1
# 3166385.0       1
# 3120745.0       1
# 3143034.0       1
# Name: GEO_X, Length: 47406, dtype: int64
# 1694794.0    1928
# 1693787.0    1830
# 1705800.0    1698
# 1694739.0    1593
# 1735292.0    1559
#              ...
# 1707765.0       1
# 1679942.0       1
# 1678854.0       1
# 1719796.0       1
# 1670730.0       1
# Name: GEO_Y, Length: 44974, dtype: int64
# -104.987485    1949
# -104.993574    1591
# -104.673812    1559
# -104.992313    1434
# -104.990480    1427
#                ...
# -105.017736       1
# -105.035393       1
# -104.871458       1
# -105.016215       1
# -105.012357       1
# Name: GEO_LON, Length: 96426, dtype: int64
# 39.739897    1909
# 39.737154    1809
# 39.769688    1696
# 39.739773    1591
# 39.849292    1559
#              ...
# 39.723997       1
# 39.668807       1
# 39.712798       1
# 39.788510       1
# 39.713440       1
# Name: GEO_LAT, Length: 95893, dtype: int64
# 3.0    108768
# 6.0     98759
# 1.0     83127
# 2.0     69866
# 4.0     64488
# 5.0     52508
# 7.0      6296
# Name: DISTRICT_ID, dtype: int64
# 611.0    32214
# 311.0    22389
# 612.0    20031
# 123.0    18292
# 623.0    17160
# 122.0    16762
# 412.0    16564
# 621.0    16396
# 323.0    14987
# 512.0    14893
# 223.0    14617
# 312.0    14313
# 313.0    14146
# 211.0    13993
# 113.0    13491
# 111.0    13024
# 622.0    12981
# 423.0    12875
# 521.0    12827
# 322.0    12667
# 421.0    12211
# 121.0    11729
# 422.0    11546
# 324.0    11423
# 411.0    11292
# 221.0    11136
# 212.0    10649
# 321.0    10646
# 511.0    10618
# 213.0     9918
# 112.0     9800
# 222.0     9582
# 522.0     8411
# 314.0     8174
# 759.0     6296
# 523.0     5759
# Name: PRECINCT_ID, dtype: int64
# five-points     26128
# central-park    20037
# capitol-hill    17421
# montbello       16337
# cbd             16281
#                 ...
# skyland          1821
# rosedale         1531
# country-club     1149
# indian-creek      645
# wellshire         549
# Name: NEIGHBORHOOD_ID, Length: 79, dtype: int64
# 1    366578
# 0    117234
# Name: IS_CRIME, dtype: int64
# 0    366304
# 1    117508
# Name: IS_TRAFFIC, dtype: int64

# %% [markdown]
# По результатам работы функции, выполненной в блоке выше, видим, что выбросов и аномальных значений нет.

# %% [markdown]
# ### 10) Столбец с максимальным средним значением после нормировки признаков через стандартное отклонение?

# %% [markdown]
# Преобразуем дату и время:

# %%
import datetime
df['REPORTED_DATE']=df.REPORTED_DATE.apply(lambda x:datetime.datetime.strptime(x,'%m/%d/%Y %I:%M:%S %p'))
df['year']=df.REPORTED_DATE.apply(lambda x:x.strftime('%Y')).astype(int)
df['month']=df.REPORTED_DATE.apply(lambda x:x.strftime('%m')).astype(int)
df['day']=df.REPORTED_DATE.apply(lambda x:x.strftime('%d')).astype(int)
df['hour']=df.REPORTED_DATE.apply(lambda x:x.strftime('%H')).astype(int)
df['minute']=df.REPORTED_DATE.apply(lambda x:x.strftime('%M')).astype(int)
df.head()
# Out:
#    INCIDENT_ID         OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0   2021224206   2021224206220200          2202                       0
# 1   2021225308   2021225308240400          2404                       0
# 2  20216009452  20216009452239900          2399                       0
# 3  20216009439  20216009439230500          2305                       0
# 4  20218017976  20218017976240400          2404                       0
#
#                OFFENSE_TYPE_ID       OFFENSE_CATEGORY_ID       REPORTED_DATE  \
# 0  burglary-residence-by-force                  burglary 2021-04-21 15:25:00
# 1       theft-of-motor-vehicle                auto-theft 2021-04-22 00:01:00
# 2                  theft-other                   larceny 2021-04-21 22:13:00
# 3     theft-items-from-vehicle  theft-from-motor-vehicle 2021-04-21 13:17:00
# 4       theft-of-motor-vehicle                auto-theft 2021-04-21 12:20:00
#
#        GEO_X      GEO_Y     GEO_LON  ...  DISTRICT_ID  PRECINCT_ID  \
# 0  3142828.0  1692472.0 -104.992161  ...          6.0        611.0
# 1  3124936.0  1664570.0 -105.056261  ...          4.0        423.0
# 2  3149191.0  1703917.0 -104.969299  ...          2.0        211.0
# 3  3146781.0  1673727.0 -104.978488  ...          3.0        313.0
# 4  3223419.0  1730557.0 -104.704438  ...          7.0        759.0
#
#    NEIGHBORHOOD_ID IS_CRIME  IS_TRAFFIC  year  month  day  hour  minute
# 0     civic-center        1           0  2021      4   21    15      25
# 1      bear-valley        1           0  2021      4   22     0       1
# 2             cole        1           0  2021      4   21    22      13
# 3       platt-park        1           0  2021      4   21    13      17
# 4              dia        1           0  2021      4   21    12      20
#
# [5 rows x 21 columns]

# %% [markdown]
# Нормируем числовые признаки через стандартное отклонение.

# %%
import math
numeric = ['INCIDENT_ID', 'OFFENSE_ID', 'GEO_X', 'GEO_Y', 'GEO_LON', 'GEO_LAT']
for column in numeric:
    df[column] = (df[column] - df[column].mean()) / (math.sqrt(df[column].var()))

# %% [markdown]
# Преобразуем тектовые значения в числовые:

# %%
text = ['OFFENSE_TYPE_ID', 'OFFENSE_CATEGORY_ID', 'NEIGHBORHOOD_ID']
for column in text:
    cur_set = set(df[column])
    i = 0
    for item in cur_set:
        df[column] = df[column].replace(item, i)
        i = i + 1

# %%
df
# Out:
#         INCIDENT_ID  OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0         -0.159371   -0.159371          2202                       0
# 1         -0.159370   -0.159370          2404                       0
# 2          1.116050    1.116050          2399                       0
# 3          1.116050    1.116050          2305                       0
# 4          1.116191    1.116191          2404                       0
# ...             ...         ...           ...                     ...
# 487992    -0.159367   -0.159367          5441                       0
# 487993    -0.159367   -0.159367          2404                       0
# 487994    -0.159367   -0.159367          2999                       1
# 487995    -0.159367   -0.159367          2404                       0
# 487996    -0.159367   -0.159367          2399                       0
#
#         OFFENSE_TYPE_ID  OFFENSE_CATEGORY_ID       REPORTED_DATE     GEO_X  \
# 0                   155                   12 2021-04-21 15:25:00 -0.031250
# 1                   173                   11 2021-04-22 00:01:00 -0.057146
# 2                    75                    9 2021-04-21 22:13:00 -0.022040
# 3                    48                    6 2021-04-21 13:17:00 -0.025528
# 4                   173                   11 2021-04-21 12:20:00  0.085396
# ...                 ...                  ...                 ...       ...
# 487992              177                    0 2021-05-14 16:04:00 -0.025588
# 487993              173                   11 2021-05-14 09:12:00 -0.041031
# 487994              117                    1 2021-05-15 06:33:00  0.062873
# 487995              173                   11 2021-05-15 02:51:00  0.005637
# 487996               75                    9 2021-05-15 11:32:00 -0.023786
#
#            GEO_Y   GEO_LON  ...  DISTRICT_ID  PRECINCT_ID  NEIGHBORHOOD_ID  \
# 0      -0.017502 -0.034726  ...          6.0        611.0               38
# 1      -0.181588 -0.067878  ...          4.0        423.0                9
# 2       0.049803 -0.022902  ...          2.0        211.0                0
# 3      -0.127738 -0.027655  ...          3.0        313.0               62
# 4       0.206467  0.114082  ...          7.0        759.0               28
# ...          ...       ...  ...          ...          ...              ...
# 487992  0.016771 -0.027471  ...          6.0        621.0               61
# 487993  0.038877 -0.047059  ...          1.0        113.0               27
# 487994  0.062517  0.085059  ...          5.0        523.0                7
# 487995  0.036283  0.012249  ...          5.0        512.0               18
# 487996 -0.012962 -0.025235  ...          6.0        623.0               37
#
#         IS_CRIME  IS_TRAFFIC  year  month  day  hour  minute
# 0              1           0  2021      4   21    15      25
# 1              1           0  2021      4   22     0       1
# 2              1           0  2021      4   21    22      13
# 3              1           0  2021      4   21    13      17
# 4              1           0  2021      4   21    12      20
# ...          ...         ...   ...    ...  ...   ...     ...
# 487992         0           1  2021      5   14    16       4
# 487993         1           0  2021      5   14     9      12
# 487994         1           0  2021      5   15     6      33
# 487995         1           0  2021      5   15     2      51
# 487996         1           0  2021      5   15    11      32
#
# [483812 rows x 21 columns]

# %% [markdown]
# Максимальное среднее значение среди столбцов с числовым значением:

# %%
max_average = -math.inf
max_name = ''
for column in numeric:
    if df[column].mean() > max_average:
        max_name = column
        max_average = df[column].mean()
print(f"{max_average} - {max_name}")
# Out:
# 2.815017748298085e-15 - OFFENSE_ID

# %% [markdown]
# По результатам работы функции, выполненной в блоке выше, видим, что столбец с максимальным средним значением после нормировки признаков - OFFENSE_ID.

# %% [markdown]
# ### 11) Столбец с целевым признаком?

# %% [markdown]
# Поскольку мы собираемся выделить районы с наибольшим или наименьшим количеством преступлений, то целевой признак – NEIGHBORHOOD_ID.

# %% [markdown]
# ### 12) Сколько объектов попадает в тренировочную выборку при использовании train_test_split с параметрами test_size = 0.3, random_state = 42?

# %% [markdown]
# Сначала исключим столбец с целевым признаком из датасета для тренировки, а также столбец REPORTED_DATE, т.к. он был переработан в столбцы year, month, day, hour, minute

# %%
df_train = df.drop(['NEIGHBORHOOD_ID', 'REPORTED_DATE'], axis=1)
df_test = df['NEIGHBORHOOD_ID']

# %% [markdown]
# Разделим данные на тренировочные и проверочные.

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df_train, df_test, test_size=.3, random_state=42)

# %%
x_train
# Out:
#         INCIDENT_ID  OFFENSE_ID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 87647      1.115278    1.115278          3612                       0
# 359337    -0.159488   -0.159488          2303                       0
# 79484     -0.159588   -0.159588          7199                       1
# 359667    -0.159499   -0.159499          2399                       0
# 251080    -0.159507   -0.159507          5707                       0
# ...             ...         ...           ...                     ...
# 261412    -0.159583   -0.159583          2303                       0
# 369051    -0.159729   -0.159729          5441                       0
# 133089    -0.299639   -0.299639          5401                       0
# 148163    -0.159640   -0.159640          1313                       2
# 123024    -0.159706   -0.159706          5441                       0
#
#         OFFENSE_TYPE_ID  OFFENSE_CATEGORY_ID     GEO_X     GEO_Y   GEO_LON  \
# 87647                23                    4 -0.031322 -0.009769 -0.034804
# 359337               29                    9 -0.035057  0.027256 -0.039485
# 79484               158                    4 -0.031843 -0.004171 -0.035457
# 359667               75                    9 -0.047652 -0.018714 -0.055566
# 251080              157                    4 -0.033932 -0.032657 -0.038159
# ...                 ...                  ...       ...       ...       ...
# 261412               29                    9 -0.055476 -0.186645 -0.065766
# 369051              177                    0 -0.055884 -0.218913 -0.066334
# 133089               91                    0 -0.028718 -0.023713 -0.031521
# 148163              150                    8  0.004961  0.085041  0.011490
# 123024              177                    0 -0.039590  0.028909 -0.045244
#
#          GEO_LAT  DISTRICT_ID  PRECINCT_ID  IS_CRIME  IS_TRAFFIC  year  month  \
# 87647   0.024075          6.0        611.0         1           0  2020      2
# 359337  0.047732          6.0        612.0         1           0  2019      8
# 79484   0.027651          6.0        611.0         1           0  2018      2
# 359667  0.018599          1.0        122.0         1           0  2019      6
# 251080  0.009521          1.0        123.0         1           0  2019      5
# ...          ...          ...          ...       ...         ...   ...    ...
# 261412 -0.088357          4.0        423.0         1           0  2018      3
# 369051 -0.108923          4.0        423.0         0           1  2016      2
# 133089  0.015148          6.0        623.0         0           1  2019      1
# 148163  0.083944          5.0        511.0         1           0  2017      6
# 123024  0.048849          1.0        123.0         0           1  2016      7
#
#         day  hour  minute
# 87647    17    15      36
# 359337   27    19       0
# 79484    21    10      48
# 359667   25    21      47
# 251080    3    11       9
# ...     ...   ...     ...
# 261412   21    15       0
# 369051   21    15      11
# 133089    4    15      46
# 148163   13     1      33
# 123024   13    17      59
#
# [338668 rows x 19 columns]

# %% [markdown]
# Как видно из размеров таблицы, в тренировочную выборку поподёт 338668 объектов.

# %%
for column in df.columns:
    print(df[column].value_counts())
# Out:
# -0.159720    8
# -0.159421    7
# -0.159413    7
# -0.159646    6
# -0.159438    6
#             ..
# -0.159644    1
# -0.159428    1
#  1.114648    1
# -0.286898    1
# -0.159566    1
# Name: INCIDENT_ID, Length: 451318, dtype: int64
#  1.114089    2
# -0.159536    1
# -0.159568    1
# -0.159659    1
# -0.159642    1
#             ..
# -0.159587    1
# -0.159651    1
# -0.159632    1
# -0.286914    1
#  1.114648    1
# Name: OFFENSE_ID, Length: 483811, dtype: int64
# 5441    79474
# 5401    34684
# 2404    33647
# 2999    33431
# 2305    31094
#         ...
# 3804        1
# 6300        1
# 5207        1
# 5303        1
# 5704        1
# Name: OFFENSE_CODE, Length: 150, dtype: int64
# 0    417477
# 1     37410
# 2     25700
# 3      2184
# 5       777
# 4       264
# Name: OFFENSE_CODE_EXTENSION, dtype: int64
# 177    79474
# 91     34684
# 173    33647
# 48     31094
# 10     25576
#        ...
# 67         1
# 143        1
# 50         1
# 144        1
# 156        1
# Name: OFFENSE_TYPE_ID, Length: 192, dtype: int64
# 0     117234
# 4      82677
# 9      50826
# 1      50539
# 6      45821
# 11     34410
# 3      26674
# 12     24861
# 8      23457
# 7      13264
# 13      6639
# 2       6390
# 10       661
# 5        359
# Name: OFFENSE_CATEGORY_ID, dtype: int64
# 2020-06-01 00:30:00    20
# 2020-06-02 00:25:00    19
# 2020-05-31 22:30:00    18
# 2020-06-24 10:12:00    16
# 2020-05-31 22:00:00    16
#                        ..
# 2019-11-27 12:55:00     1
# 2017-08-22 09:17:00     1
# 2017-08-03 11:42:00     1
# 2018-02-03 21:43:00     1
# 2018-06-18 17:05:00     1
# Name: REPORTED_DATE, Length: 409552, dtype: int64
# -0.029365    2054
# -0.031843    1596
#  0.097782    1570
# -0.031322    1472
# -0.030549    1428
#              ...
#  0.034504       1
#  0.003597       1
#  0.013536       1
#  0.013273       1
#  0.029556       1
# Name: GEO_X, Length: 47406, dtype: int64
# -0.003847    1928
# -0.009769    1830
#  0.060877    1698
# -0.004171    1593
#  0.234312    1559
#              ...
#  0.066787       1
# -0.111683       1
# -0.248064       1
#  0.131705       1
#  0.069198       1
# Name: GEO_Y, Length: 44974, dtype: int64
# -0.032308    1949
# -0.035457    1591
#  0.129921    1559
# -0.034804    1434
# -0.033856    1427
#              ...
# -0.053085       1
#  0.091879       1
#  0.012474       1
#  0.015875       1
#  0.035624       1
# Name: GEO_LON, Length: 96426, dtype: int64
#  0.027821    1909
#  0.024075    1809
#  0.068505    1696
#  0.027651    1591
#  0.177217    1559
#              ...
# -0.084026       1
# -0.051000       1
#  0.103537       1
#  0.102511       1
# -0.018138       1
# Name: GEO_LAT, Length: 95893, dtype: int64
# 3.0    108768
# 6.0     98759
# 1.0     83127
# 2.0     69866
# 4.0     64488
# 5.0     52508
# 7.0      6296
# Name: DISTRICT_ID, dtype: int64
# 611.0    32214
# 311.0    22389
# 612.0    20031
# 123.0    18292
# 623.0    17160
# 122.0    16762
# 412.0    16564
# 621.0    16396
# 323.0    14987
# 512.0    14893
# 223.0    14617
# 312.0    14313
# 313.0    14146
# 211.0    13993
# 113.0    13491
# 111.0    13024
# 622.0    12981
# 423.0    12875
# 521.0    12827
# 322.0    12667
# 421.0    12211
# 121.0    11729
# 422.0    11546
# 324.0    11423
# 411.0    11292
# 221.0    11136
# 212.0    10649
# 321.0    10646
# 511.0    10618
# 213.0     9918
# 112.0     9800
# 222.0     9582
# 522.0     8411
# 314.0     8174
# 759.0     6296
# 523.0     5759
# Name: PRECINCT_ID, dtype: int64
# 61    26128
# 18    20037
# 37    17421
# 40    16337
# 39    16281
#       ...
# 11     1821
# 71     1531
# 35     1149
# 57      645
# 50      549
# Name: NEIGHBORHOOD_ID, Length: 79, dtype: int64
# 1    366578
# 0    117234
# Name: IS_CRIME, dtype: int64
# 0    366304
# 1    117508
# Name: IS_TRAFFIC, dtype: int64
# 2018    92607
# 2017    92290
# 2016    89724
# 2019    88999
# 2020    83494
# 2021    36698
# Name: year, dtype: int64
# 5     45340
# 1     45111
# 4     42774
# 3     42726
# 8     41027
# 2     40798
# 7     39367
# 9     39279
# 10    38996
# 6     37715
# 12    35366
# 11    35313
# Name: month, dtype: int64
# 8     16389
# 6     16296
# 21    16255
# 22    16185
# 19    16182
# 3     16152
# 5     16143
# 17    16083
# 12    16057
# 11    16041
# 16    16005
# 18    15957
# 2     15946
# 15    15936
# 4     15898
# 20    15893
# 7     15861
# 10    15853
# 14    15851
# 9     15845
# 13    15787
# 23    15689
# 1     15631
# 24    15578
# 27    15519
# 26    15409
# 28    15278
# 25    15184
# 29    14839
# 30    14609
# 31     9461
# Name: day, dtype: int64
# 16    31196
# 15    30798
# 17    29515
# 14    28700
# 13    28240
# 12    27873
# 18    26835
# 11    26438
# 10    25908
# 9     24757
# 19    23663
# 8     21274
# 20    21019
# 22    18701
# 21    18539
# 23    16693
# 7     14793
# 0     13588
# 1     12365
# 2     11207
# 3      9227
# 6      8084
# 4      7582
# 5      6817
# Name: hour, dtype: int64
# 0     13410
# 30    11703
# 45     9756
# 15     9560
# 20     9353
# 40     9111
# 10     9083
# 50     9031
# 25     8478
# 55     8469
# 5      8365
# 35     8329
# 19     7861
# 54     7856
# 34     7850
# 12     7850
# 53     7838
# 42     7823
# 57     7817
# 47     7813
# 41     7802
# 4      7790
# 9      7785
# 11     7782
# 26     7756
# 36     7754
# 56     7752
# 28     7749
# 43     7748
# 24     7746
# 13     7744
# 7      7740
# 27     7740
# 8      7740
# 38     7720
# 2      7719
# 48     7697
# 51     7690
# 18     7689
# 17     7681
# 3      7680
# 6      7673
# 33     7660
# 14     7659
# 52     7657
# 31     7649
# 39     7645
# 23     7605
# 59     7598
# 58     7596
# 37     7586
# 22     7586
# 44     7576
# 21     7572
# 32     7542
# 46     7539
# 16     7493
# 49     7474
# 29     7435
# 1      7407
# Name: minute, dtype: int64

# %%
df.dtypes
# Out:
# INCIDENT_ID                      float64
# OFFENSE_ID                       float64
# OFFENSE_CODE                       int64
# OFFENSE_CODE_EXTENSION             int64
# OFFENSE_TYPE_ID                    int64
# OFFENSE_CATEGORY_ID                int64
# REPORTED_DATE             datetime64[ns]
# GEO_X                            float64
# GEO_Y                            float64
# GEO_LON                          float64
# GEO_LAT                          float64
# DISTRICT_ID                      float64
# PRECINCT_ID                      float64
# NEIGHBORHOOD_ID                    int64
# IS_CRIME                           int64
# IS_TRAFFIC                         int64
# year                               int32
# month                              int32
# day                                int32
# hour                               int32
# minute                             int32
# dtype: object

# %% [markdown]
# ### 13) Между какими признаками наблюдается линейная зависимость (корреляция)?

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data["column_name"] = df_train.columns
vif_data["VIF"] = [variance_inflation_factor(df_train.values, i) for i in range(len(df_train.columns))]

# %% [markdown]
# Выведем признаки со значением VIF $\geq$ 10:

# %%
vif_data.loc[vif_data['VIF'] >= 10.0]
# Out:
#      column_name           VIF
# 0    INCIDENT_ID           inf
# 1     OFFENSE_ID           inf
# 2   OFFENSE_CODE  2.372146e+04
# 6          GEO_X  2.090827e+05
# 7          GEO_Y  1.691780e+03
# 8        GEO_LON  1.305669e+05
# 9        GEO_LAT  3.973774e+03
# 10   DISTRICT_ID  3.577924e+03
# 11   PRECINCT_ID  3.874093e+03
# 12      IS_CRIME  1.341828e+03
# 13    IS_TRAFFIC  4.299490e+02
# 14          year  1.808549e+03

# %% [markdown]
# Как мы видим, наибольший показатель VIF $\geq$ 10 у INCIDENT_ID, OFFENSE_ID, OFFENSE_CODE, GEO_X, GEO_Y, GEO_LON, GEO_LAT, DISTRICT_ID, PRECINCT_ID, IS_CRIME, IS_TRAFFIC, year

# %% [markdown]
# ### 14) Сколько признаков достаточно для объяснения 90% дисперсии после применения метода PCA?

# %% [markdown]
# Стандартизируем данные:

# %%
from sklearn import preprocessing
stand_X = pd.DataFrame(preprocessing.scale(x_train), columns = x_train.columns)

# %% [markdown]
# Применим PCA так, чтобы он объяснил 90% дисперсии:

# %%
from sklearn.decomposition import PCA
for i in range(1, len(stand_X.columns)):
    pca = PCA(n_components=i)
    pca.fit(stand_X)
    print(i, sum(pca.explained_variance_ratio_))
# Out:
# 1 0.21045094721963134
# 2 0.3853202730611467
# 3 0.4910738303035732
# 4 0.592028624894279
# 5 0.6525318402724691
# 6 0.7100709120953597
# 7 0.7634204888703511
# 8 0.8160730063309259
# 9 0.8678143956151481
# 10 0.9173963560079272
# 11 0.9595187543341178
# 12 0.9832948722246759
# 13 0.9992347739094721
# 14 0.9998188576054453
# 15 0.999902849760987
# 16 0.9999719035575223
# 17 0.9999999860174998
# 18 1.0

# %% [markdown]
# Видим, что достаточно 10 признаков.

# %% [markdown]
# ### 15) Какой признак вносит наибольший вклад в первую компоненту?

# %%
pca = PCA(n_components=10)
x = pca.fit(stand_X)

# %%
first_component = pca.components_[0]
greatest_contribution_i = 0
greatest_contribution = first_component[greatest_contribution_i]

for i in range(0, len(first_component)):
    if  abs(first_component[i]) >  abs(greatest_contribution):
        greatest_contribution = first_component[i]
        greatest_contribution_i = i
print(greatest_contribution_i, greatest_contribution)
# Out:
# 6 0.4987356763196083

# %% [markdown]
# Наибольший по модулю вклад в первую компоненту вносит 6 признак.

# %%
stand_X.iloc[:, 6]
# Out:
# 0        -0.031141
# 1        -0.034990
# 2        -0.031678
# 3        -0.047972
# 4        -0.033830
#             ...
# 338663   -0.056037
# 338664   -0.056458
# 338665   -0.028457
# 338666    0.006258
# 338667   -0.039662
# Name: GEO_X, Length: 338668, dtype: float64

# %% [markdown]
# Видим, что это признак GEO_X

# %% [markdown]
# ### Доп. задание: построить двухмерное представление данных с помощью алгоритма t-SNE. На сколько кластеров визуально на ваш взгляд разделяется выборка?

# %%
less_dimensional_X = pca.transform(stand_X)

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components = 2, random_state = 0)
tsne_results = tsne.fit_transform(less_dimensional_X)

# %%
tsne_df = pd.DataFrame({'X':tsne_results[:,0], 'Y':tsne_results[:,1], 'real_ans':y_train})
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 20))
sns.scatterplot(x="X", y="Y", data=tsne_df);

# %% [markdown]
# Визуально можно выделить от 100 до 106 кластеров.
